# %%
from glob import glob
import pickle

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
file_list_S = glob('data3/model_S*')
file_list_M = glob('data3/model_M*')
file_list_L = glob('data3/model_L*')
file_list_XL = glob('data3/model_XL*')

# %%
file_list = glob('data3/*')

# %%
all_data_dicts = {
    'S':[],
    'M':[],
    'L':[],
    'X':[]
}

for filename in file_list:
    with open(filename, 'rb') as handle:
        this_dict = pickle.load(handle)
        all_data_dicts[filename[12]].append(this_dict)

# %%
all_data_dicts
# Out:
# {'S': [{'sig_ratio': 0.5,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 50,
#    'result': [[50, 1], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 40,
#    'result': [[40, -1], [40, -1], [40, -1], [40, -1]]},
#   {'sig_ratio': 0.1,
#    'dimension': 1,
#    'result': [[1, 1], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.01,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 1]]},
#   {'sig_ratio': 0.15,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 15,
#    'result': [[15, 2], [15, 1], [15, 1], [15, 1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 25,
#    'result': [[25, 2], [25, 1], [25, -1], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 60,
#    'result': [[60, 0], [60, 1], [60, 1], [60, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 100,
#    'result': [[100, 0], [100, 1], [100, 0], [100, 1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 5,
#    'result': [[5, 3], [5, 2], [5, 3], [5, 3]]},
#   {'sig_ratio': 0.2,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 5,
#    'result': [[5, 0], [5, 0], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 70,
#    'result': [[70, 0], [70, 1], [70, 1], [70, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 2], [25, 1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.02,
#    'dimension': 2,
#    'result': [[2, -1], [2, 0], [2, -1], [2, 1]]},
#   {'sig_ratio': 0.05,
#    'dimension': 2,
#    'result': [[2, 0], [2, 1], [2, 0], [2, 1]]},
#   {'sig_ratio': 0.001,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 5,
#    'result': [[5, 0], [5, 0], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 30,
#    'result': [[30, 0], [30, 1], [30, 1], [30, 1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 2,
#    'result': [[2, 0], [2, 1], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 20,
#    'result': [[20, 0], [20, 1], [20, 1], [20, 1]]},
#   {'sig_ratio': 0.1,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 1], [2, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 1], [20, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 30,
#    'result': [[30, 1], [30, 1], [30, 0], [30, 1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 5,
#    'result': [[5, 0], [5, 2], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 5,
#    'result': [[5, 0], [5, 0], [5, 0], [5, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.02,
#    'dimension': 5,
#    'result': [[5, 0], [5, 1], [5, -1], [5, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.005,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.05,
#    'dimension': 5,
#    'result': [[5, 1], [5, -1], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 1,
#    'result': [[1, 1], [1, 0], [1, 1], [1, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 10,
#    'result': [[10, 1], [10, 3], [10, 2], [10, 1]]},
#   {'sig_ratio': 0.02,
#    'dimension': 10,
#    'result': [[10, -1], [10, -1], [10, -1], [10, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 1]]},
#   {'sig_ratio': 0.02,
#    'dimension': 1,
#    'result': [[1, 1], [1, -1], [1, 0], [1, -1]]},
#   {'sig_ratio': 0.05,
#    'dimension': 1,
#    'result': [[1, 3], [1, 0], [1, 1], [1, 1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 10,
#    'result': [[10, 0], [10, -1], [10, 1], [10, 3]]},
#   {'sig_ratio': 0.1,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]}],
#  'M': [{'sig_ratio': 0.1,
#    'dimension': 30,
#    'result': [[30, 0], [30, 1], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.005,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 5], [30, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 20,
#    'result': [[20, 18], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 60,
#    'result': [[60, 2], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 1,
#    'result': [[1, 1], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.02,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.1,
#    'dimension': 20,
#    'result': [[20, -1], [20, 0], [20, 0], [20, 1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 5,
#    'result': [[5, -1], [5, -1], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 5,
#    'result': [[5, -1], [5, 7], [5, -1], [5, 14]]},
#   {'sig_ratio': 0.1,
#    'dimension': 10,
#    'result': [[10, 1], [10, 0], [10, 19], [10, 17]]},
#   {'sig_ratio': 0.15,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 1], [80, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 2,
#    'result': [[2, 0], [2, -1], [2, -1], [2, -1]]},
#   {'sig_ratio': 0.15,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 10,
#    'result': [[10, 0], [10, -1], [10, 1], [10, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 4], [10, 2]]},
#   {'sig_ratio': 0.3,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.05,
#    'dimension': 2,
#    'result': [[2, 1], [2, 1], [2, -1], [2, -1]]},
#   {'sig_ratio': 0.15,
#    'dimension': 15,
#    'result': [[15, 5], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 15,
#    'result': [[15, -1], [15, 6], [15, 4], [15, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 5,
#    'result': [[5, 0], [5, 3], [5, 15], [5, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 5,
#    'result': [[5, 7], [5, 15], [5, -1], [5, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 15,
#    'result': [[15, 0], [15, 1], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 1], [40, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 4], [15, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 5,
#    'result': [[5, -1], [5, -1], [5, -1], [5, 7]]},
#   {'sig_ratio': 0.3,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 5,
#    'result': [[5, 10], [5, -1], [5, -1], [5, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 2]]},
#   {'sig_ratio': 0.15,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 5,
#    'result': [[5, -1], [5, 0], [5, 8], [5, 3]]},
#   {'sig_ratio': 0.5,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 25,
#    'result': [[25, 1], [25, 0], [25, 1], [25, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 1,
#    'result': [[1, 0], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 10,
#    'result': [[10, -1], [10, -1], [10, -1], [10, -1]]},
#   {'sig_ratio': 0.15,
#    'dimension': 25,
#    'result': [[25, 1], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.01,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]}],
#  'L': [{'sig_ratio': 0.2,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 5,
#    'result': [[5, 1], [5, 0], [5, 0], [5, 1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 1,
#    'result': [[1, 1], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 1,
#    'result': [[1, -1], [1, 13], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.005,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.01,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, 0], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.05,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.02,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 5,
#    'result': [[5, 0], [5, -1], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 5,
#    'result': [[5, 0], [5, 0], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.1,
#    'dimension': 2,
#    'result': [[2, -1], [2, -1], [2, -1], [2, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 5,
#    'result': [[5, -1], [5, 0], [5, 0], [5, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 40,
#    'result': [[40, 0], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 15,
#    'result': [[15, 0], [15, 0], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 10,
#    'result': [[10, -1], [10, 0], [10, 0], [10, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]}],
#  'X': [{'sig_ratio': 0.3,
#    'dimension': 1,
#    'result': [[1, -1], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 10,
#    'result': [[10, -1], [10, 4], [10, 0], [10, 11]]},
#   {'sig_ratio': 0.15,
#    'dimension': 2,
#    'result': [[2, -1], [2, 0], [2, -1], [2, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.001,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 80,
#    'result': [[80, 0], [80, 0], [80, 0], [80, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, 0], [1, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 1,
#    'result': [[1, 0], [1, 0], [1, -1], [1, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 90,
#    'result': [[90, 0], [90, 0], [90, 0], [90, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 10,
#    'result': [[10, 0], [10, 0], [10, 0], [10, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 5,
#    'result': [[5, 5], [5, -1], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 5,
#    'result': [[5, -1], [5, 14], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.02,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.05,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, -1], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 20,
#    'result': [[20, 0], [20, 0], [20, -1], [20, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 30,
#    'result': [[30, 0], [30, 0], [30, 0], [30, 0]]},
#   {'sig_ratio': 0.3,
#    'dimension': 5,
#    'result': [[5, 0], [5, 0], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.2,
#    'dimension': 100,
#    'result': [[100, 0], [100, 0], [100, 0], [100, 0]]},
#   {'sig_ratio': 0.01,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 25,
#    'result': [[25, 0], [25, 0], [25, 0], [25, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, 0], [1, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 70,
#    'result': [[70, 0], [70, 0], [70, 0], [70, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 25,
#    'result': [[25, 0], [25, 5], [25, -1], [25, 2]]},
#   {'sig_ratio': 0.3,
#    'dimension': 2,
#    'result': [[2, 0], [2, 0], [2, 0], [2, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 60,
#    'result': [[60, 0], [60, 0], [60, 0], [60, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 15,
#    'result': [[15, 0], [15, -1], [15, 0], [15, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 40,
#    'result': [[40, 3], [40, 0], [40, 0], [40, 0]]},
#   {'sig_ratio': 0.15,
#    'dimension': 5,
#    'result': [[5, -1], [5, -1], [5, -1], [5, -1]]},
#   {'sig_ratio': 0.005,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.3,
#    'dimension': 10,
#    'result': [[10, -1], [10, -1], [10, -1], [10, -1]]},
#   {'sig_ratio': 0.1,
#    'dimension': 1,
#    'result': [[1, -1], [1, -1], [1, -1], [1, -1]]},
#   {'sig_ratio': 0.5,
#    'dimension': 40,
#    'result': [[40, 8], [40, 0], [40, -1], [40, 0]]},
#   {'sig_ratio': 0.2,
#    'dimension': 50,
#    'result': [[50, 0], [50, 0], [50, 0], [50, 0]]},
#   {'sig_ratio': 0.5,
#    'dimension': 15,
#    'result': [[15, -1], [15, 0], [15, 0], [15, 0]]}]}

# %%
numbers_S = {}
for event in all_data_dicts['S']:
    sig_ratio, dim = event['sig_ratio'], event['dimension']
    if sig_ratio in numbers_S:
        numbers_S[sig_ratio] = max(numbers_S[sig_ratio], dim)
    else:
        numbers_S[sig_ratio] = dim

# %%
numbers_S
# Out:
# {0.5: 100,
#  0.15: 100,
#  0.05: 40,
#  0.2: 100,
#  0.1: 100,
#  0.01: 1,
#  0.3: 100,
#  0.02: 10,
#  0.001: 1,
#  0.005: 1}

# %%
numbers_M = {}
for event in all_data_dicts['M']:
    sig_ratio, dim = event['sig_ratio'], event['dimension']
    if sig_ratio in numbers_M:
        numbers_M[sig_ratio] = max(numbers_M[sig_ratio], dim)
    else:
        numbers_M[sig_ratio] = dim

# %%
numbers_L = {}
for event in all_data_dicts['L']:
    sig_ratio, dim = event['sig_ratio'], event['dimension']
    if sig_ratio in numbers_L:
        numbers_L[sig_ratio] = max(numbers_L[sig_ratio], dim)
    else:
        numbers_L[sig_ratio] = dim

# %%
numbers_XL = {}
for event in all_data_dicts['X']:
    sig_ratio, dim = event['sig_ratio'], event['dimension']
    if sig_ratio in numbers_XL:
        numbers_XL[sig_ratio] = max(numbers_XL[sig_ratio], dim)
    else:
        numbers_XL[sig_ratio] = dim

# %%
def sort_dict(d):
    return dict(sorted(d.items()))

# %%
numbers_S = sort_dict(numbers_S)
numbers_M = sort_dict(numbers_M)
numbers_L = sort_dict(numbers_L)
numbers_XL = sort_dict(numbers_XL)

# %%
    
fig, ax = plt.subplots(figsize = (12,10))

ax.plot(numbers_S.keys(), numbers_S.values(),label = 'layers: [50, 25]')
ax.plot(numbers_M.keys(), numbers_M.values(),label = 'layers: [100, 50]')
ax.plot(numbers_L.keys(), numbers_L.values(),label = 'layers: [100, 100, 50]')

ax.plot(numbers_XL.keys(), numbers_XL.values(),label = 'layers: [200, 200, 100]')


ax.legend()

ax.set_title('how well it picks up low ratios')
ax.set_xlabel('sig ratio')

ax.set_ylabel('max number of dimensions and still can train')
ax.set_xlim((0,0.25))
# ax.set_ylim((-1, 20))
ax.grid(axis="x", which = 'both')

plt.show()

# %%
export = {
    'S':numbers_S,
    'M':numbers_M,
    'L':numbers_L,
    'XL':numbers_XL
}

export
# Out:
# {'S': {0.001: 1,
#   0.005: 1,
#   0.01: 1,
#   0.02: 10,
#   0.05: 40,
#   0.1: 100,
#   0.15: 100,
#   0.2: 100,
#   0.3: 100,
#   0.5: 100},
#  'M': {0.001: 10,
#   0.005: 1,
#   0.01: 1,
#   0.02: 1,
#   0.05: 5,
#   0.1: 100,
#   0.15: 100,
#   0.2: 100,
#   0.3: 100,
#   0.5: 100},
#  'L': {0.001: 1,
#   0.005: 1,
#   0.01: 1,
#   0.02: 1,
#   0.05: 1,
#   0.1: 2,
#   0.15: 100,
#   0.2: 100,
#   0.3: 100,
#   0.5: 100},
#  'XL': {0.001: 1,
#   0.005: 1,
#   0.01: 1,
#   0.02: 1,
#   0.05: 1,
#   0.1: 1,
#   0.15: 5,
#   0.2: 100,
#   0.3: 10,
#   0.5: 100}}

# %%
with open('data_export/main_no_box/res3.pickle', 'wb') as handle:
    pickle.dump(export, handle, protocol=pickle.HIGHEST_PROTOCOL)
